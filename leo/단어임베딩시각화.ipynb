# %% [markdown]
# # 단어 임베딩 시각화

# %%
import os
import sys

sys.path.insert(0, os.path.abspath('/notebooks/embedding'))
sys.path.insert(0, os.path.abspath('/notebooks/embedding/models'))
#sys.path.append('/notebooks/embedding')

# %%
# wget https://github.com/dongjun-Lee/kor2vec/raw/master/test_dataset/kor_analogy_semantic.txt -P /notebooks/embedding/data/raw

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
from models.word_eval import WordEmbeddingEvaluator

# %% [markdown]
# ## 코드 4-40 단어 임베딩의 t-SNE 2차원 시각화 word2vec

# %%
vecs_txt_fname='/notebooks/embedding/data/word-embeddings/word2vec/word2vec'
method='word2vec'
dim=100
tokenizer_name='mecab'

# %%
model = WordEmbeddingEvaluator(vecs_txt_fname=vecs_txt_fname, method=method, dim=dim, tokenizer_name=tokenizer_name)
# Out:
# /usr/local/lib/python3.5/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
# 단어 임베딩 t-SNE 2차원 시각화
model.visualize_words(eval_fname)
# Out:
# save @ /notebooks/embedding/words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/words.png')
img

# %% [markdown]
# ## 코드 4-41 단어 벡터 간 유사도 시각화

# %%
vecs_txt_fname='/notebooks/embedding/data/word-embeddings/word2vec/word2vec'
method='word2vec'
dim=100
tokenizer_name='mecab'

# %%
model = WordEmbeddingEvaluator(vecs_txt_fname=vecs_txt_fname, method=method, dim=dim, tokenizer_name=tokenizer_name)
# Out:
# /usr/local/lib/python3.5/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
# 단어 벡터 유사도 시각화
model.visualize_between_words(eval_fname)
# Out:
# save @ /notebooks/embedding/between-words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/between-words.png')
img

# %% [markdown]
# ## fasttext

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
vecs_txt_fname='/notebooks/embedding/data/word-embeddings/fasttext/fasttext.vec'
vecs_bin_fname='/notebooks/embedding/data/word-embeddings/fasttext/fasttext.bin'
method='fasttext'
dim=100
tokenizer_name='mecab'

# %%
model = WordEmbeddingEvaluator(vecs_txt_fname=vecs_txt_fname, method=method, dim=dim, tokenizer_name=tokenizer_name)

# %%
model.visualize_words(eval_fname)
# Out:
# save @ /notebooks/embedding/words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/words.png')
img

# %%
# 단어 벡터 유사도 시각화
model.visualize_between_words(eval_fname)
# Out:
# save @ /notebooks/embedding/between-words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/between-words.png')
img

# %% [markdown]
# # glove

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
vecs_txt_fname='/notebooks/embedding/data/word-embeddings/glove/glove.txt'
method='glove'
dim=100
tokenizer_name='mecab'

# %%
model = WordEmbeddingEvaluator(vecs_txt_fname=vecs_txt_fname, method=method, dim=dim, tokenizer_name=tokenizer_name)

# %%
model.visualize_words(eval_fname)
# Out:
# save @ /notebooks/embedding/words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/words.png')
img

# %%
# 단어 벡터 유사도 시각화
model.visualize_between_words(eval_fname)
# Out:
# save @ /notebooks/embedding/between-words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/between-words.png')
img

# %% [markdown]
# ## swivel

# %%
eval_fname='/notebooks/embedding/data/raw/kor_analogy_semantic.txt'

# %%
vecs_txt_fname='/notebooks/embedding/data/word-embeddings/swivel/row_embedding.tsv'
method='swivel'
dim=100
tokenizer_name='mecab'

# %%
model = WordEmbeddingEvaluator(vecs_txt_fname=vecs_txt_fname, method=method, dim=dim, tokenizer_name=tokenizer_name)

# %%
model.visualize_words(eval_fname)
# Out:
# save @ /notebooks/embedding/words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/words.png')
img

# %%
# 단어 벡터 유사도 시각화
model.visualize_between_words(eval_fname)
# Out:
# save @ /notebooks/embedding/between-words.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image
img=Image(filename='/notebooks/embedding/between-words.png')
img
